# %%
import sqlite3

import pandas as pd

# %%
df = pd.read_csv('../data/raw/Cereal.csv', index_col=0, sep=';', decimal=',')

# %%
df.head()
# Out:
#                                    mfr         type calories protein  fat  \
# name
# String                     Categorical  Categorical      Int     Int  Int
# 100% Bran                            N            C       70       4    1
# 100% Natural Bran                    Q            C      120       3    5
# All-Bran                             K            C       70       4    1
# All-Bran with Extra Fiber            K            C       50       4    0
#
#                           sodium  fiber  carbo sugars potass vitamins shelf  \
# name
# String                       Int  Float  Float    Int    Int      Int   Int
# 100% Bran                    130     10      5      6    280       25     3
# 100% Natural Bran             15      2      8      8    135        0     3
# All-Bran                     260      9      7      5    320       25     3
# All-Bran with Extra Fiber    140     14      8      0    330       25     3
#
# ...

# %%
df = df.drop(df.index[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       77 non-null     object
#  1   type      77 non-null     object
#  2   calories  77 non-null     object
#  3   protein   77 non-null     object
#  4   fat       77 non-null     object
#  5   sodium    77 non-null     object
#  6   fiber     77 non-null     object
#  7   carbo     77 non-null     object
#  8   sugars    77 non-null     object
#  9   potass    77 non-null     object
#  10  vitamins  77 non-null     object
#  11  shelf     77 non-null     object
#  12  weight    77 non-null     object
#  13  cups      77 non-null     object
#  14  rating    77 non-null     object
# dtypes: object(15)
# memory usage: 9.6+ KB

# %%
df.describe()
# Out:
#        mfr type calories protein fat sodium fiber carbo sugars potass  \
# count   77   77       77      77  77     77    77    77     77     77
# unique   7    2       11       6   5     27    13    22     17     36
# top      K    C      110       3   1      0     0    13      3     90
# freq    23   74       29      28  30      9    19     8     13      5
#
#        vitamins shelf weight cups      rating
# count        77    77     77   77          77
# unique        3     3      7   12          77
# top          25     3      1    1  68.402.973
# freq         63    36     64   30           1

# %%
conn = sqlite3.connect('../data/db/Cereal.db')
cur = conn.cursor()

# %%
df.reset_index(inplace=True)
df.to_sql('cereals', conn, if_exists='replace', index=True, index_label='id')
# Out:
# 77

# %%
query = "SELECT * FROM cereals"

pd.read_sql_query(query, conn)
# Out:
#     id                       name mfr type calories protein fat sodium fiber  \
# 0    0                  100% Bran   N    C       70       4   1    130    10
# 1    1          100% Natural Bran   Q    C      120       3   5     15     2
# 2    2                   All-Bran   K    C       70       4   1    260     9
# 3    3  All-Bran with Extra Fiber   K    C       50       4   0    140    14
# 4    4             Almond Delight   R    C      110       2   2    200     1
# ..  ..                        ...  ..  ...      ...     ...  ..    ...   ...
# 72  72                    Triples   G    C      110       2   1    250     0
# 73  73                       Trix   G    C      110       1   1    140     0
# 74  74                 Wheat Chex   R    C      100       3   1    230     3
# 75  75                   Wheaties   G    C      100       3   1    200     3
# 76  76        Wheaties Honey Gold   G    C      110       2   1    200     1
#
# ...
